# %%
import boto3
from datetime import datetime 
import pandas as pd
import os
import io
from pymongo import MongoClient
from user_agents import parse
from apscheduler.schedulers.blocking import BlockingScheduler



def loop():   
    year=datetime.now().year
    month=datetime.now().month
    day=datetime.now().day
    hour=datetime.now().hour
    path = f"year={year:04d}/month={month:02d}/day={day:02d}/hour=15/"
    prefix = path
    dataframe_collector(prefix)
    print("1")

def dataframe_collector(prefix):
    all_csv_files = s3.list_objects_v2(Bucket=bucket, Prefix=prefix)
    collect_dataframes = []
    for csv_file in all_csv_files['Contents']:
        if csv_file['Key'].endswith('.csv'):
            csv_file_data = s3.get_object(Bucket=bucket, Key=csv_file['Key'])['Body'].read().decode('utf-8')
            tmp_df = pd.read_csv(io.StringIO(csv_file_data))
            collect_dataframes.append(tmp_df)
    final_dataframe = pd.concat(collect_dataframes, ignore_index=True)
    parser_function(final_dataframe)
    print("2")


def parser_function(dataframe):
    dataframe['browser'] = dataframe['user_agent'].apply(lambda x: parse(x).browser.family)
    dataframe['device'] = dataframe['user_agent'].apply(lambda x: parse(x).device.family)
    transformer(dataframe)
    print("3")


def transformer(dataframe):
    dataframe=dataframe.drop(['user_agent','Unnamed: 0'],axis=1)
    dataframe['page_views'] = 1
    dataframe = dataframe.rename(columns={'user_cookie': 'unique_user'})
    dataframe = dataframe.groupby(['site', 'device', 'browser']).agg({'page_views': 'sum', 'unique_user': 'nunique'})
    store_records(dataframe)
    print("4")


def store_records(dataframe):
    data = dataframe.to_dict('records')
    collection.insert_many(data)
    print("5")


if __name__=="__main__":
    bucket = "test-bucket"
    s3 = boto3.client(
    "s3",
    endpoint_url="http://localhost:9000",
    aws_access_key_id="usmanadmin",
    aws_secret_access_key="usmanadmin",
    )
    client = MongoClient("mongodb://localhost:27017/")
    db = client["UserActivityDatabase"]
    collection = db["userstraffic"]
    scheduler = BlockingScheduler()
    scheduler.add_job(loop, 'interval', minutes=1)
    scheduler.start()
# Out:
# 5
# 4
# 3
# 2
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 70
#      68 scheduler = BlockingScheduler()
#      69 scheduler.add_job(loop, 'interval', minutes=1)
# ---> 70 scheduler.start()
#
# File ~/.local/lib/python3.10/site-packages/apscheduler/schedulers/blocking.py:21, in BlockingScheduler.start(self, *args, **kwargs)
#      18     self._event = Event()
#      20 super(BlockingScheduler, self).start(*args, **kwargs)
# ---> 21 self._main_loop()
#
# File ~/.local/lib/python3.10/site-packages/apscheduler/schedulers/blocking.py:30, in BlockingScheduler._main_loop(self)
#      28 wait_seconds = TIMEOUT_MAX
#      29 while self.state != STATE_STOPPED:
# ---> 30     self._event.wait(wait_seconds)
#      31     self._event.clear()
#      32     wait_seconds = self._process_jobs()
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
cursor = db.userstraffic.find({})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ca6'), 'page_views': 9507, 'user_cookie': 7380}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ca7'), 'page_views': 9632, 'user_cookie': 7321}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ca8'), 'page_views': 9577, 'user_cookie': 7375}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ca9'), 'page_views': 9677, 'user_cookie': 7421}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362caa'), 'page_views': 9546, 'user_cookie': 7332}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cab'), 'page_views': 9626, 'user_cookie': 7361}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cac'), 'page_views': 9508, 'user_cookie': 7285}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cad'), 'page_views': 9737, 'user_cookie': 7507}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cae'), 'page_views': 9772, 'user_cookie': 7477}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362caf'), 'page_views': 19134, 'user_cookie': 11607}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb0'), 'page_views': 9529, 'user_cookie': 7308}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb1'), 'page_views': 9604, 'user_cookie': 7370}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb2'), 'page_views': 9611, 'user_cookie': 7369}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb3'), 'page_views': 9645, 'user_cookie': 7398}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb4'), 'page_views': 9525, 'user_cookie': 7300}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb5'), 'page_views': 9512, 'user_cookie': 7325}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb6'), 'page_views': 9599, 'user_cookie': 7333}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb7'), 'page_views': 9517, 'user_cookie': 7366}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb8'), 'page_views': 9730, 'user_cookie': 7409}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cb9'), 'page_views': 19149, 'user_cookie': 11638}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cba'), 'page_views': 9503, 'user_cookie': 7278}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cbb'), 'page_views': 9515, 'user_cookie': 7269}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cbc'), 'page_views': 9522, 'user_cookie': 7313}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cbd'), 'page_views': 9501, 'user_cookie': 7292}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cbe'), 'page_views': 9381, 'user_cookie': 7250}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cbf'), 'page_views': 9539, 'user_cookie': 7341}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc0'), 'page_views': 9467, 'user_cookie': 7310}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc1'), 'page_views': 9594, 'user_cookie': 7365}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc2'), 'page_views': 9577, 'user_cookie': 7421}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc3'), 'page_views': 18920, 'user_cookie': 11536}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc4'), 'page_views': 9591, 'user_cookie': 7332}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc5'), 'page_views': 9555, 'user_cookie': 7335}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc6'), 'page_views': 9548, 'user_cookie': 7313}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc7'), 'page_views': 9669, 'user_cookie': 7411}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc8'), 'page_views': 9624, 'user_cookie': 7339}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cc9'), 'page_views': 9472, 'user_cookie': 7331}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cca'), 'page_views': 9496, 'user_cookie': 7284}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ccb'), 'page_views': 9526, 'user_cookie': 7342}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ccc'), 'page_views': 9783, 'user_cookie': 7472}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ccd'), 'page_views': 19236, 'user_cookie': 11661}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cce'), 'page_views': 9575, 'user_cookie': 7338}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362ccf'), 'page_views': 9474, 'user_cookie': 7278}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd0'), 'page_views': 9485, 'user_cookie': 7278}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd1'), 'page_views': 9491, 'user_cookie': 7319}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd2'), 'page_views': 9475, 'user_cookie': 7235}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd3'), 'page_views': 9629, 'user_cookie': 7434}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd4'), 'page_views': 9460, 'user_cookie': 7310}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd5'), 'page_views': 9604, 'user_cookie': 7373}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd6'), 'page_views': 9570, 'user_cookie': 7355}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd7'), 'page_views': 18976, 'user_cookie': 11526}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd8'), 'page_views': 9430, 'user_cookie': 7299}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362cd9'), 'page_views': 9541, 'user_cookie': 7326}
# {'_id': ObjectId('63f79cb2a8a7e17e1d362
# {'_id': ObjectId('63f79e82849a442ba3f03fe2'), 'page_views': 18880, 'user_cookie': 11558}
# {'_id': ObjectId('63f79faa849a442ba3f04072'), 'page_views': 9507, 'user_cookie': 7380}
# {'_id': ObjectId('63f79faa849a442ba3f04073'), 'page_views': 9632, 'user_cookie': 7321}
# {'_id': ObjectId('63f79faa849a442ba3f04074'), 'page_views': 9577, 'user_cookie': 7375}
# {'_id': ObjectId('63f79faa849a442ba3f04075'), 'page_views': 9677, 'user_cookie': 7421}
# {'_id': ObjectId('63f79faa849a442ba3f04076'), 'page_views': 9546, 'user_cookie': 7332}
# {'_id': ObjectId('63f79faa849a442ba3f04077'), 'page_views': 9626, 'user_cookie': 7361}
# {'_id': ObjectId('63f79faa849a442ba3f04078'), 'page_views': 9508, 'user_cookie': 7285}
# {'_id': ObjectId('63f79faa849a442ba3f04079'), 'page_views': 9737, 'user_cookie': 7507}
# {'_id': ObjectId('63f79faa849a442ba3f0407a'), 'page_views': 9772, 'user_cookie': 7477}
# {'_id': ObjectId('63f79faa849a442ba3f0407b'), 'page_views': 19134, 'user_cookie': 11607}
# {'_id': ObjectId('63f79faa849a442ba3f0407c'), 'page_views': 9529, 'user_cookie': 7308}
# {'_id': ObjectId('63f79faa849a442ba3f0407d'), 'page_views': 9604, 'user_cookie': 7370}
# {'_id': ObjectId('63f79faa849a442ba3f0407e'), 'page_views': 9611, 'user_cookie': 7369}
# {'_id': ObjectId('63f79faa849a442ba3f0407f'), 'page_views': 9645, 'user_cookie': 7398}
# {'_id': ObjectId('63f79faa849a442ba3f04080'), 'page_views': 9525, 'user_cookie': 7300}
# {'_id': ObjectId('63f79faa849a442ba3f04081'), 'page_views': 9512, 'user_cookie': 7325}
# {'_id': ObjectId('63f79faa849a442ba3f04082'), 'page_views': 9599, 'user_cookie': 7333}
# {'_id': ObjectId('63f79faa849a442ba3f04083'), 'page_views': 9517, 'user_cookie': 7366}
# {'_id': ObjectId('63f79faa849a442ba3f04084'), 'page_views': 9730, 'user_cookie': 7409}
# {'_id': ObjectId('63f79faa849a442ba3f04085'), 'page_views': 19149, 'user_cookie': 11638}
# {'_id': ObjectId('63f79faa849a442ba3f04086'), 'page_views': 9503, 'user_cookie': 7278}
# {'_id': ObjectId('63f79faa849a442ba3f04087'), 'page_views': 9515, 'user_cookie': 7269}
# {'_id': ObjectId('63f79faa849a442ba3f04088'), 'page_views': 9522, 'user_cookie': 7313}
# {'_id': ObjectId('63f79faa849a442ba3f04089'), 'page_views': 9501, 'user_cookie': 7292}
# {'_id': ObjectId('63f79faa849a442ba3f0408a'), 'page_views': 9381, 'user_cookie': 7250}
# {'_id': ObjectId('63f79faa849a442ba3f0408b'), 'page_views': 9539, 'user_cookie': 7341}
# {'_id': ObjectId('63f79faa849a442ba3f0408c'), 'page_views': 9467, 'user_cookie': 7310}
# {'_id': ObjectId('63f79faa849a442ba3f0408d'), 'page_views': 9594, 'user_cookie': 7365}
# {'_id': ObjectId('63f79faa849a442ba3f0408e'), 'page_views': 9577, 'user_cookie': 7421}
# {'_id': ObjectId('63f79faa849a442ba3f0408f'), 'page_views': 18920, 'user_cookie': 11536}
# {'_id': ObjectId('63f79faa849a442ba3f04090'), 'page_views': 9591, 'user_cookie': 7332}
# {'_id': ObjectId('63f79faa849a442ba3f04091'), 'page_views': 9555, 'user_cookie': 7335}
# {'_id': ObjectId('63f79faa849a442ba3f04092'), 'page_views': 9548, 'user_cookie': 7313}
# {'_id': ObjectId('63f79faa849a442ba3f04093'), 'page_views': 9669, 'user_cookie': 7411}
# {'_id': ObjectId('63f79faa849a442ba3f04094'), 'page_views': 9624, 'user_cookie': 7339}
# {'_id': ObjectId('63f79faa849a442ba3f04095'), 'page_views': 9472, 'user_cookie': 7331}
# {'_id': ObjectId('63f79faa849a442ba3f04096'), 'page_views': 9496, 'user_cookie': 7284}
# {'_id': ObjectId('63f79faa849a442ba3f04097'), 'page_views': 9526, 'user_cookie': 7342}
# {'_id': ObjectId('63f79faa849a442ba3f04098'), 'page_views': 9783, 'user_cookie': 7472}
# {'_id': ObjectId('63f79faa849a442ba3f04099'), 'page_views': 19236, 'user_cookie': 11661}
# {'_id': ObjectId('63f79faa849a442ba3f0409a'), 'page_views': 9575, 'user_cookie': 7338}
# {'_id': ObjectId('63f79faa849a442ba3f0409b'), 'page_views': 9474, 'user_cookie': 7278}
# {'_id': ObjectId('63f79faa849a442ba3f0409c'), 'page_views': 9485, 'user_cookie': 7278}
# {'_id': ObjectId('63f79faa849a442ba3f0409d'), 'page_views': 9491, 'user_cookie': 7319}
# {'_id': ObjectId('63f79faa849a442ba3f0409e'), 'page_views': 9475, 'user_cookie': 7235}
# {'_id': ObjectId('63f79faa849a442ba3f0409f'), 'page_views': 9629, 'user_cookie': 7434}
# {'_id': ObjectId('63f79faa849a442ba3f040a0'), 'page_views': 9460, 'user_cookie': 7310}
# {'_id': ObjectId('63f79faa849a442ba3f040a1'), 'page_views': 9604, 'user_cookie': 7373}
# {'_id': ObjectId('63f79faa849a442ba3f040a2'), 'page_views': 9570, 'user_cookie': 7355}
# {'_id': ObjectId('63f79faa849a442ba3f040a3'), 'page_views': 18976, 'user_cookie': 11526}
# {'_id': ObjectId('63f79faa849a442ba3f040a4'), 'page_views': 9430, 'user_cookie': 7299}
# {'_id': ObjectId('63f79faa849a442ba3f040a5'), 'page_views': 9541, 'user_cookie': 7326}
# {'_id': ObjectId('63f79faa849a442ba3f040a6'), 'page_views': 9348, 'user_cookie': 7248}
# {'_id': ObjectId('63f79faa849a442ba3f040a7'), 'page_views': 9501, 'user_cookie': 7362}
# {'_id': ObjectId('63f79faa849a442ba3f040a8'), 'page_views': 9657, 'user_cookie': 7418}
# {'_id': ObjectId('63f79faa849a442ba3f040a9'), 'page_views': 9650, 'user_cookie': 7400}
# {'_id': ObjectId('63f79faa849a442ba3f040aa'), 'page_views': 9846, 'user_cookie': 7513}
# {'_id': ObjectId('63f79faa849a442ba3f040ab'), 'page_views': 9496, 'user_cookie': 7309}
# {'_id': ObjectId('63f79faa849a442ba3f040ac'), 'page_views': 9679, 'user_cookie': 7413}
# {'_id': ObjectId('63f79faa849a442ba3f040ad'), 'page_views': 19043, 'user_cookie': 11624}
# ...
# {'_id': ObjectId('63f7a7d502fb6582bbf4c48f'), 'page_views': 9594, 'unique_user': 7365}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c490'), 'page_views': 9577, 'unique_user': 7421}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c491'), 'page_views': 18920, 'unique_user': 11536}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c492'), 'page_views': 9591, 'unique_user': 7332}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c493'), 'page_views': 9555, 'unique_user': 7335}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c494'), 'page_views': 9548, 'unique_user': 7313}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c495'), 'page_views': 9669, 'unique_user': 7411}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c496'), 'page_views': 9624, 'unique_user': 7339}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c497'), 'page_views': 9472, 'unique_user': 7331}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c498'), 'page_views': 9496, 'unique_user': 7284}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c499'), 'page_views': 9526, 'unique_user': 7342}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49a'), 'page_views': 9783, 'unique_user': 7472}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49b'), 'page_views': 19236, 'unique_user': 11661}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49c'), 'page_views': 9575, 'unique_user': 7338}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49d'), 'page_views': 9474, 'unique_user': 7278}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49e'), 'page_views': 9485, 'unique_user': 7278}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c49f'), 'page_views': 9491, 'unique_user': 7319}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a0'), 'page_views': 9475, 'unique_user': 7235}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a1'), 'page_views': 9629, 'unique_user': 7434}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a2'), 'page_views': 9460, 'unique_user': 7310}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a3'), 'page_views': 9604, 'unique_user': 7373}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a4'), 'page_views': 9570, 'unique_user': 7355}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a5'), 'page_views': 18976, 'unique_user': 11526}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a6'), 'page_views': 9430, 'unique_user': 7299}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a7'), 'page_views': 9541, 'unique_user': 7326}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a8'), 'page_views': 9348, 'unique_user': 7248}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4a9'), 'page_views': 9501, 'unique_user': 7362}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4aa'), 'page_views': 9657, 'unique_user': 7418}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4ab'), 'page_views': 9650, 'unique_user': 7400}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4ac'), 'page_views': 9846, 'unique_user': 7513}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4ad'), 'page_views': 9496, 'unique_user': 7309}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4ae'), 'page_views': 9679, 'unique_user': 7413}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4af'), 'page_views': 19043, 'unique_user': 11624}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b0'), 'page_views': 9598, 'unique_user': 7382}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b1'), 'page_views': 9632, 'unique_user': 7353}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b2'), 'page_views': 9619, 'unique_user': 7367}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b3'), 'page_views': 9632, 'unique_user': 7382}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b4'), 'page_views': 9390, 'unique_user': 7205}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b5'), 'page_views': 9610, 'unique_user': 7310}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b6'), 'page_views': 9474, 'unique_user': 7292}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b7'), 'page_views': 9472, 'unique_user': 7238}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b8'), 'page_views': 9784, 'unique_user': 7485}
# {'_id': ObjectId('63f7a7d502fb6582bbf4c4b9'), 'page_views': 18880, 'unique_user': 11558}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c502'), 'page_views': 9507, 'unique_user': 7380}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c503'), 'page_views': 9632, 'unique_user': 7321}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c504'), 'page_views': 9577, 'unique_user': 7375}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c505'), 'page_views': 9677, 'unique_user': 7421}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c506'), 'page_views': 9546, 'unique_user': 7332}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c507'), 'page_views': 9626, 'unique_user': 7361}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c508'), 'page_views': 9508, 'unique_user': 7285}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c509'), 'page_views': 9737, 'unique_user': 7507}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50a'), 'page_views': 9772, 'unique_user': 7477}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50b'), 'page_views': 19134, 'unique_user': 11607}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50c'), 'page_views': 9529, 'unique_user': 7308}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50d'), 'page_views': 9604, 'unique_user': 7370}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50e'), 'page_views': 9611, 'unique_user': 7369}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c50f'), 'page_views': 9645, 'unique_user': 7398}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c510'), 'page_views': 9525, 'unique_user': 7300}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c511'), 'page_views': 9512, 'unique_user': 7325}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c512'), 'page_views': 9599, 'unique_user': 7333}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c513'), 'page_views': 9517, 'unique_user': 7366}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c514'), 'page_views': 9730, 'unique_user': 7409}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c515'), 'page_views': 19149, 'unique_user': 11638}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c516'), 'page_views': 9503, 'unique_user': 7278}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c517'), 'page_views': 9515, 'unique_user': 7269}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c518'), 'page_views': 9522, 'unique_user': 7313}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c519'), 'page_views': 9501, 'unique_user': 7292}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51a'), 'page_views': 9381, 'unique_user': 7250}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51b'), 'page_views': 9539, 'unique_user': 7341}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51c'), 'page_views': 9467, 'unique_user': 7310}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51d'), 'page_views': 9594, 'unique_user': 7365}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51e'), 'page_views': 9577, 'unique_user': 7421}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c51f'), 'page_views': 18920, 'unique_user': 11536}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c520'), 'page_views': 9591, 'unique_user': 7332}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c521'), 'page_views': 9555, 'unique_user': 7335}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c522'), 'page_views': 9548, 'unique_user': 7313}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c523'), 'page_views': 9669, 'unique_user': 7411}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c524'), 'page_views': 9624, 'unique_user': 7339}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c525'), 'page_views': 9472, 'unique_user': 7331}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c526'), 'page_views': 9496, 'unique_user': 7284}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c527'), 'page_views': 9526, 'unique_user': 7342}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c528'), 'page_views': 9783, 'unique_user': 7472}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c529'), 'page_views': 19236, 'unique_user': 11661}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52a'), 'page_views': 9575, 'unique_user': 7338}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52b'), 'page_views': 9474, 'unique_user': 7278}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52c'), 'page_views': 9485, 'unique_user': 7278}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52d'), 'page_views': 9491, 'unique_user': 7319}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52e'), 'page_views': 9475, 'unique_user': 7235}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c52f'), 'page_views': 9629, 'unique_user': 7434}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c530'), 'page_views': 9460, 'unique_user': 7310}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c531'), 'page_views': 9604, 'unique_user': 7373}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c532'), 'page_views': 9570, 'unique_user': 7355}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c533'), 'page_views': 18976, 'unique_user': 11526}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c534'), 'page_views': 9430, 'unique_user': 7299}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c535'), 'page_views': 9541, 'unique_user': 7326}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c536'), 'page_views': 9348, 'unique_user': 7248}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c537'), 'page_views': 9501, 'unique_user': 7362}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c538'), 'page_views': 9657, 'unique_user': 7418}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c539'), 'page_views': 9650, 'unique_user': 7400}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53a'), 'page_views': 9846, 'unique_user': 7513}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53b'), 'page_views': 9496, 'unique_user': 7309}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53c'), 'page_views': 9679, 'unique_user': 7413}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53d'), 'page_views': 19043, 'unique_user': 11624}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53e'), 'page_views': 9598, 'unique_user': 7382}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c53f'), 'page_views': 9632, 'unique_user': 7353}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c540'), 'page_views': 9619, 'unique_user': 7367}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c541'), 'page_views': 9632, 'unique_user': 7382}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c542'), 'page_views': 9390, 'unique_user': 7205}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c543'), 'page_views': 9610, 'unique_user': 7310}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c544'), 'page_views': 9474, 'unique_user': 7292}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c545'), 'page_views': 9472, 'unique_user': 7238}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c546'), 'page_views': 9784, 'unique_user': 7485}
# {'_id': ObjectId('63f7a8ce02fb6582bbf4c547'), 'page_views': 18880, 'unique_user': 11558}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60e5'), 'page_views': 9507, 'unique_user': 7380}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60e6'), 'page_views': 9632, 'unique_user': 7321}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60e7'), 'page_views': 9577, 'unique_user': 7375}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60e8'), 'page_views': 9677, 'unique_user': 7421}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60e9'), 'page_views': 9546, 'unique_user': 7332}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ea'), 'page_views': 9626, 'unique_user': 7361}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60eb'), 'page_views': 9508, 'unique_user': 7285}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ec'), 'page_views': 9737, 'unique_user': 7507}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ed'), 'page_views': 9772, 'unique_user': 7477}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ee'), 'page_views': 19134, 'unique_user': 11607}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ef'), 'page_views': 9529, 'unique_user': 7308}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f0'), 'page_views': 9604, 'unique_user': 7370}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f1'), 'page_views': 9611, 'unique_user': 7369}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f2'), 'page_views': 9645, 'unique_user': 7398}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f3'), 'page_views': 9525, 'unique_user': 7300}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f4'), 'page_views': 9512, 'unique_user': 7325}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f5'), 'page_views': 9599, 'unique_user': 7333}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f6'), 'page_views': 9517, 'unique_user': 7366}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f7'), 'page_views': 9730, 'unique_user': 7409}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f8'), 'page_views': 19149, 'unique_user': 11638}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60f9'), 'page_views': 9503, 'unique_user': 7278}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60fa'), 'page_views': 9515, 'unique_user': 7269}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60fb'), 'page_views': 9522, 'unique_user': 7313}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60fc'), 'page_views': 9501, 'unique_user': 7292}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60fd'), 'page_views': 9381, 'unique_user': 7250}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60fe'), 'page_views': 9539, 'unique_user': 7341}
# {'_id': ObjectId('63f7abe38424b2eb7d1b60ff'), 'page_views': 9467, 'unique_user': 7310}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6100'), 'page_views': 9594, 'unique_user': 7365}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6101'), 'page_views': 9577, 'unique_user': 7421}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6102'), 'page_views': 18920, 'unique_user': 11536}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6103'), 'page_views': 9591, 'unique_user': 7332}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6104'), 'page_views': 9555, 'unique_user': 7335}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6105'), 'page_views': 9548, 'unique_user': 7313}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6106'), 'page_views': 9669, 'unique_user': 7411}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6107'), 'page_views': 9624, 'unique_user': 7339}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6108'), 'page_views': 9472, 'unique_user': 7331}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6109'), 'page_views': 9496, 'unique_user': 7284}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610a'), 'page_views': 9526, 'unique_user': 7342}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610b'), 'page_views': 9783, 'unique_user': 7472}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610c'), 'page_views': 19236, 'unique_user': 11661}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610d'), 'page_views': 9575, 'unique_user': 7338}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610e'), 'page_views': 9474, 'unique_user': 7278}
# {'_id': ObjectId('63f7abe38424b2eb7d1b610f'), 'page_views': 9485, 'unique_user': 7278}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6110'), 'page_views': 9491, 'unique_user': 7319}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6111'), 'page_views': 9475, 'unique_user': 7235}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6112'), 'page_views': 9629, 'unique_user': 7434}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6113'), 'page_views': 9460, 'unique_user': 7310}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6114'), 'page_views': 9604, 'unique_user': 7373}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6115'), 'page_views': 9570, 'unique_user': 7355}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6116'), 'page_views': 18976, 'unique_user': 11526}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6117'), 'page_views': 9430, 'unique_user': 7299}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6118'), 'page_views': 9541, 'unique_user': 7326}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6119'), 'page_views': 9348, 'unique_user': 7248}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611a'), 'page_views': 9501, 'unique_user': 7362}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611b'), 'page_views': 9657, 'unique_user': 7418}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611c'), 'page_views': 9650, 'unique_user': 7400}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611d'), 'page_views': 9846, 'unique_user': 7513}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611e'), 'page_views': 9496, 'unique_user': 7309}
# {'_id': ObjectId('63f7abe38424b2eb7d1b611f'), 'page_views': 9679, 'unique_user': 7413}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6120'), 'page_views': 19043, 'unique_user': 11624}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6121'), 'page_views': 9598, 'unique_user': 7382}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6122'), 'page_views': 9632, 'unique_user': 7353}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6123'), 'page_views': 9619, 'unique_user': 7367}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6124'), 'page_views': 9632, 'unique_user': 7382}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6125'), 'page_views': 9390, 'unique_user': 7205}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6126'), 'page_views': 9610, 'unique_user': 7310}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6127'), 'page_views': 9474, 'unique_user': 7292}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6128'), 'page_views': 9472, 'unique_user': 7238}
# {'_id': ObjectId('63f7abe38424b2eb7d1b6129'), 'page_views': 9784, 'unique_user': 7485}
# {'_id': ObjectId('63f7abe38424b2eb7d1b612a'), 'page_views': 18880, 'unique_user': 11558}
